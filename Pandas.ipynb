# %% [markdown]
# ## Pandas
# - Manejo de archivos
# - Series (1D)
# - Dataframes (2D)
# - Panels (3D)

# %%
import pandas as pd

# %%
#Estructura de datos mas sencilla en pandas.
series = pd.Series([ 5, 10, 15 , 20, 25])
series
# Out:
# 0     5
# 1    10
# 2    15
# 3    20
# 4    25
# dtype: int64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
series[3]
# Out:
# 20

# %%
#convertir lista a serie de pandas
letter = ['a','b','c','d','f','h','i']
letter_serie = pd.Series(letter)
letter_serie
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    f
# 5    h
# 6    i
# dtype: object

# %%
#convetir lista a dataframe en pandas.
letter_dataframe = pd.DataFrame(letter)
letter_dataframe
# Out:
#    0
# 0  a
# 1  b
# 2  c
# 3  d
# 4  f
# 5  h
# 6  i

# %%
# Convertir diccionario de python en dataFrame.
data = {'Name': ['Juan','Ana', 'jose', 'Arturo'],
        'Edad': [25,18,23,17],
        'Pais': ['MX', 'CO','BR', 'MX']
        }
x_dataframe  =  pd.DataFrame(data)

x_dataframe
# Out:
#      Name  Edad Pais
# 0    Juan    25   MX
# 1     Ana    18   CO
# 2    jose    23   BR
# 3  Arturo    17   MX

# %%
# import data with pandas
songs2018_data = pd.read_csv('./canciones-2018_b2c776e4-1cce-40eb-b3e7-591ea6d29f83.csv')
songs2018_data.head(5)
# Out:
#                       id                          name       artists  \
# 0  6DCZcSspjsKoFjzjrWoCd                    God's Plan         Drake
# 1  3ee8Jmje8o58CHK66QrVC                          SAD!  XXXTENTACION
# 2  0e7ipj03S05BNilyu5bRz    rockstar (feat. 21 Savage)   Post Malone
# 3  3swc6WTsr7rl9DqQKQA55  Psycho (feat. Ty Dolla $ign)   Post Malone
# 4  2G7V7zsVDxg1yRsu7Ew9R                In My Feelings         Drake
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.754   0.449  7.0    -9.211   1.0       0.1090        0.0332
# 1         0.740   0.613  8.0    -4.880   1.0       0.1450        0.2580
# 2         0.587   0.535  5.0    -6.090   0.0       0.0898        0.1170
# 3         0.739   0.559  8.0    -8.011   1.0       0.1170        0.5800
# 4         0.835   0.626  1.0    -5.833   1.0       0.1250        0.0589
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# ...

# %%
# LLamar una columna
songs2018_data['name']
# Out:
# 0                            God's Plan
# 1                                  SAD!
# 2            rockstar (feat. 21 Savage)
# 3          Psycho (feat. Ty Dolla $ign)
# 4                        In My Feelings
#                     ...
# 95                    Rewrite The Stars
# 96    I Miss You (feat. Julia Michaels)
# 97                           No Brainer
# 98          Dusk Till Dawn - Radio Edit
# 99                           Be Alright
# Name: name, Length: 100, dtype: object

# %%
#O tambien de la siguiente forma
songs2018_data.name
# Out:
# 0                            God's Plan
# 1                                  SAD!
# 2            rockstar (feat. 21 Savage)
# 3          Psycho (feat. Ty Dolla $ign)
# 4                        In My Feelings
#                     ...
# 95                    Rewrite The Stars
# 96    I Miss You (feat. Julia Michaels)
# 97                           No Brainer
# 98          Dusk Till Dawn - Radio Edit
# 99                           Be Alright
# Name: name, Length: 100, dtype: object

# %%
# Ver informacion de un dato en particular.
info = songs2018_data.iloc[15]
info
# Out:
# id                     3GCdLUSnKSMJhs4Tj6CV3
# name                All The Stars (with SZA)
# artists                       Kendrick Lamar
# danceability                           0.698
# energy                                 0.633
# key                                      8.0
# loudness                              -4.946
# mode                                     1.0
# speechiness                           0.0597
# acousticness                          0.0605
# instrumentalness                    0.000194
# liveness                              0.0926
# valence                                0.552
# tempo                                 96.924
# duration_ms                         232187.0
# time_signature                           4.0
# Name: 15, dtype: object

# %%
#informacion en el final del dataframe.
songs2018_data.tail()
# Out:
#                        id                               name       artists  \
# 95  630sXRhIcfwr2e4RdNtjK                  Rewrite The Stars     Zac Efron
# 96  2xmrfQpmS2iJExTlklLoA  I Miss You (feat. Julia Michaels)  Clean Bandit
# 97  5WvAo7DNuPRmk4APhdPzi                         No Brainer     DJ Khaled
# 98  1j4kHkkpqZRBwE0A4CN4Y        Dusk Till Dawn - Radio Edit          ZAYN
# 99  3EPXxR3ImUwfayaurPi3c                         Be Alright    Dean Lewis
#
#     danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 95         0.684   0.619  10.0    -7.005   1.0       0.0386        0.0716
# 96         0.638   0.658   3.0    -6.318   1.0       0.0456        0.2450
# 97         0.552   0.760   0.0    -4.706   1.0       0.3420        0.0733
# 98         0.258   0.437  11.0    -6.593   0.0       0.0390        0.1010
# 99         0.553   0.586  11.0    -6.319   1.0       0.0362        0.6970
#
# ...

# %%
#tamaño del dataframe.
songs2018_data.shape
# Out:
# (100, 16)

# %%
#Descripcion de una columna en especifico
songs2018_data.duration_ms.describe()
# Out:
# count       100.000000
# mean     205206.780000
# std       40007.893404
# min       95467.000000
# 25%      184680.000000
# 50%      205047.500000
# 75%      221493.250000
# max      417920.000000
# Name: duration_ms, dtype: float64

# %%
#Ordenar un dataframe
songs2018_data.sort_index(axis = 0,  ascending= False)
# Out:
#                        id                               name       artists  \
# 99  3EPXxR3ImUwfayaurPi3c                         Be Alright    Dean Lewis
# 98  1j4kHkkpqZRBwE0A4CN4Y        Dusk Till Dawn - Radio Edit          ZAYN
# 97  5WvAo7DNuPRmk4APhdPzi                         No Brainer     DJ Khaled
# 96  2xmrfQpmS2iJExTlklLoA  I Miss You (feat. Julia Michaels)  Clean Bandit
# 95  630sXRhIcfwr2e4RdNtjK                  Rewrite The Stars     Zac Efron
# ..                    ...                                ...           ...
# 4   2G7V7zsVDxg1yRsu7Ew9R                     In My Feelings         Drake
# 3   3swc6WTsr7rl9DqQKQA55       Psycho (feat. Ty Dolla $ign)   Post Malone
# 2   0e7ipj03S05BNilyu5bRz         rockstar (feat. 21 Savage)   Post Malone
# 1   3ee8Jmje8o58CHK66QrVC                               SAD!  XXXTENTACION
# 0   6DCZcSspjsKoFjzjrWoCd                         God's Plan         Drake
#
# ...

# %%
# Reto Agrupar y ordenar 3 columnas del set de datos anterior.
songs_v2 = songs2018_data[['name', 'artists', 'energy']]
songs_v2.sort_index(ascending=False)
# Out:
#                                  name       artists  energy
# 99                         Be Alright    Dean Lewis   0.586
# 98        Dusk Till Dawn - Radio Edit          ZAYN   0.437
# 97                         No Brainer     DJ Khaled   0.760
# 96  I Miss You (feat. Julia Michaels)  Clean Bandit   0.658
# 95                  Rewrite The Stars     Zac Efron   0.619
# ..                                ...           ...     ...
# 4                      In My Feelings         Drake   0.626
# 3        Psycho (feat. Ty Dolla $ign)   Post Malone   0.559
# 2          rockstar (feat. 21 Savage)   Post Malone   0.535
# 1                                SAD!  XXXTENTACION   0.613
# 0                          God's Plan         Drake   0.449
#
# [100 rows x 3 columns]
